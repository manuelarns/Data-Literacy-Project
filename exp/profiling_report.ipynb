# %% [markdown]
# # Profiling Report
#
# We use this automated *Pandas Profiling Report* to gain a first induition of the dataset before and after preprocessing.

# %%
import pandas_profiling as pp
import pandas as pd
from src.preprocessing import load_data, complete_preprocessing

# %%
# before preprocessing
_, salaries, _ = load_data()
salaries.profile_report()
# Out:
# Summarize dataset:   6%|▋         | 1/16 [00:00<00:02,  6.30it/s, Describe variable:salary]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Developer/Data-Litaracy-Project/venv/lib/python3.8/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~/Developer/Data-Litaracy-Project/venv/lib/python3.8/site-packages/pandas_profiling/profile_report.py:418, in ProfileReport._repr_html_(self)
#     416 def _repr_html_(self) -> None:
#     417     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 418     self.to_notebook_iframe()
#
# ...

# %%
# we additionally look at duplicates

print(salaries.loc[salaries.duplicated()].job_title)
print("DevOps part of dataset:", 371/2451)
# Out:
# 992                  DevOps Engineer
# 993                  DevOps Engineer
# 994                  DevOps Engineer
# 995                  DevOps Engineer
# 996                  DevOps Engineer
# 997                  DevOps Engineer
# 998                  DevOps Engineer
# 999                  DevOps Engineer
# 1000                 DevOps Engineer
# 1001                 DevOps Engineer
# 1002                 DevOps Engineer
# 1003                 DevOps Engineer
# 1004                 DevOps Engineer
# 1005                 DevOps Engineer
# 1006                 DevOps Engineer
# 1007                 DevOps Engineer
# 1008                 DevOps Engineer
# 1009                 DevOps Engineer
# 1010                 DevOps Engineer
# 1011                 DevOps Engineer
# 1012                 DevOps Engineer
# 1215                 DevOps Engineer
# 1333                 DevOps Engineer
# 1356    Information Security Analyst
# 1432                 DevOps Engineer
# ...

# %%
#preprocessed data
salaries_p = complete_preprocessing()
salaries_p.profile_report()
# Out:
# /Users/manuelarns/Developer/Data-Litaracy-Project/exp/src/preprocessing.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_data['gdp_per_capita'] = (gdp_data['gdp_md_est'] / gdp_data['pop_est'] * 1000000)
# Summarize dataset:   5%|▍         | 1/21 [00:00<00:04,  4.69it/s, Describe variable:employment_type]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Developer/Data-Litaracy-Project/venv/lib/python3.8/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# ...
